# %% [markdown]
# Ten program wypisuje "A kuku".

# %%
print("A kuku")

# %%
print("A kuku 2")

# %% [markdown]
# ### Ćwiczenie 1
# Napisz program wypisujący "Ala ma kota"

# %% [markdown]
# Teraz będzie kod

# %%
list(range(1, 9))

# %%
list(range(9, 0, -1))
